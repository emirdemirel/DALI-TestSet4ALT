# %% [markdown]
# # DALI-Test4ALT

# %% [markdown]
# ## PART 1: RETRIEVING AUDIO

# %% [markdown]
#   This is a tutorial that shows how to retrieve the audio files for the DALI-test4ALT from their corresponding Youtube links.
#
#   - For this, we exploit the identifiers within the DALI-v1.0 dataset.
#
#   - We created a CSV file which contains the DALI identifiers, song titles, artist ID, gender info and release years that will be used to retrieve data from Youtube.

# %%
import os, re
import pandas as pd
import DALI as dali_code
from youtubesearchpython import VideosSearch, ChannelsSearch
from youtube_dl import YoutubeDL
import unidecode

# %% [markdown]
# Declare the locations of the metadata file and directory to save the audio files.

# %%
INPUT_CSV_DIR = './DALI_TestSet4ALT.csv'
SAVE_DIR = './audio'

# %%
if not os.path.exists(SAVE_DIR):
    os.mkdir(SAVE_DIR)

# %%
data = pd.read_csv(INPUT_CSV_DIR,index_col=0)
data.head(10)
# Out:
#                                                  SONG_TITLE            ARTIST  \
# DALI_ID
# 44a2455abc0e4fb397a396d2cd1ebeb9       Caught In The Middle                A1
# 15d6e9e88ced41dfbff38ba2f3e1d885                All For You       Ace Of Base
# a59e44a4c910443a87f068b177200fdc           Life Is A Flower       Ace Of Base
# ae91bcda73944695b7756ddc066c3e02             Beautiful Life       Ace Of Base
# d6e3cf403653490f8366bf77cbc0f186                   Unstable             Adema
# 7a1642003f574713a6e25e5ee549fce6  When You Walk In The Room  Agnetha Faltskog
# 8eb15ad6d17f41b68009fe3848930dee                Love Stoned            Akcent
# b63d71b7ec6b4c5e9f53a87f83fcd73e                 Hallelujah   Alexandra Burke
# ac0279efad294261b4c7dc0b86eaaec5       Destination Calabria      Alex Gaudino
# 1478242633aa4628aa9a88ca6f54130a       No More Mr. Nice Guy      Alice Cooper
#
#                                  GENDER  RELEASE_YEAR  \
# DALI_ID
# 44a2455abc0e4fb397a396d2cd1ebeb9      M        2002.0
# 15d6e9e88ced41dfbff38ba2f3e1d885      F        2010.0
# a59e44a4c910443a87f068b177200fdc      F        1998.0
# ae91bcda73944695b7756ddc066c3e02      F        1995.0
# d6e3cf403653490f8366bf77cbc0f186      M        2003.0
# 7a1642003f574713a6e25e5ee549fce6      F        2004.0
# 8eb15ad6d17f41b68009fe3848930dee      M           NaN
# b63d71b7ec6b4c5e9f53a87f83fcd73e      F        2009.0
# ac0279efad294261b4c7dc0b86eaaec5      M        2008.0
# 1478242633aa4628aa9a88ca6f54130a      M        1973.0
#
#                                                                              LYRICS
# DALI_ID
# 44a2455abc0e4fb397a396d2cd1ebeb9  YOU SAID THAT LOVE WAS JUST A STATE OF MIND A ...
# 15d6e9e88ced41dfbff38ba2f3e1d885  TRIED TO WRITE YOU A LOVE SONG THOUGHT I COULD...
# a59e44a4c910443a87f068b177200fdc  WE LIVE IN A FREE WORLD I WHISTLE DOWN THE WIN...
# ae91bcda73944695b7756ddc066c3e02  YOU CAN DO WHAT YOU WANT JUST SEIZE THE DAY WH...
# d6e3cf403653490f8366bf77cbc0f186  I WANTED TO KNOW WHO YOU REALLY ARE I NEEDED T...
# 7a1642003f574713a6e25e5ee549fce6  I CAN FEEL A NEW EXPRESSION ON MY FACE I CAN F...
# 8eb15ad6d17f41b68009fe3848930dee  HOW DEEP IS YOUR LOVE BRING THE SUN OUT BABY H...
# b63d71b7ec6b4c5e9f53a87f83fcd73e  I HEARD THERE WAS A SECRET CHORD THAT DAVID PL...
# ac0279efad294261b4c7dc0b86eaaec5  DESTINATION UNKNOWN KNOWN KNOWN KNOWN KNOWN UN...
# 1478242633aa4628aa9a88ca6f54130a  I USED TO BE SUCH A SWEET SWEET THING 'TIL THE...

# %% [markdown]
# Define functions for the audio retrieval procedure.

# %%
def download_audio_from_youtube(dali_id,link,output_dir):
    
    try:
        audio_downloader = YoutubeDL({
                                'format': 'bestaudio/best',
                                'postprocessors': [{
                                'key': 'FFmpegExtractAudio',
                                'preferredcodec': 'mp3',
                                'preferredquality': '192',
                                                   }],
                                'outtmpl': os.path.join(output_dir,dali_id + '.mp3'),
                                'quiet': False
                                                 })
        audio_downloader.extract_info(link)
        
    except:
        
        print('Download with python failed!')
        print('Trying with API on bash.')
        os.system(f"""youtube-dl -o "{output_dir}/{dali_id}.mp3" --extract-audio -x --audio-format mp3 {link}""")

# %%
def normalize_text(text): 
    # Convert to lowercase to match with search results 
    # AND REMOVE SPECIAL ALL CHARACTERS LIKE " (,),!,..."
    # AND REMOVE ACCENTS (NORMALIZE TEXT)
    return unidecode.unidecode(re.sub(r"[^a-zA-Z0-9'(-)(/) ]",r'',text.lower()))

# %%
def retrieve_audio_for_dali_test(entry,save_dir,success):
    
    success = False
    
    #missing = []
    #vid_titles = []
    
    # PARSE SONG ID INFO TO BE USED FOR SEARCHING ON YOUTUBE
    
    dali_id = entry[0]
    
 
    song_title = normalize_text(entry[1]['SONG_TITLE'])
    artist_id = normalize_text(entry[1]['ARTIST'])
    year = str(entry[1]['RELEASE_YEAR'])

    try:
        year = int(year)   # CHECK IF RELEASE_YEAR INFO IS AVAILABLE
        search_title = song_title + ' ' + artist_id + ' ' + year
    except:
        # IF RELEASE_YER = NaN, THEN USE ARTIST AND SONG TITLES ONLY FOR THE SEARCH
        search_title = song_title + ' ' + artist_id
        
    # FIRST LIST OF SEARCH QUERIES, TO CHECK IF ALL EXIST IN THE 
    # YOUTUBE VIDEO TITLE    
    search_queries_1 = [song_title,artist_id]         
    
    # SECOND LIST OF SEARCH QUERIES, TO CHECK IF ANY EXISTS IN THE 
    # YOUTUBE VIDEO TITLE. THESE ARE DETERMINED TO RETRIEVE THE VERSIONS
    # USED IN DALI_TestSet4ALT DATASET
    search_queries_2 = ['official','lyrics']
    
    # THIRD LIST OF SEARCH QUERIES, TO CHECK IF ANY DOES NOT EXIST IN THE 
    # YOUTUBE VIDEO TITLE. THESE ARE DETERMINED TO RETRIEVE THE VERSIONS
    # USED IN DALI_TestSet4ALT DATASET
    search_queries_3 = ['remix']
    
    #THE ABOVE DEFINED LIST OF QUERIES CAN BE EXTENDED DEPENDING ON THE GOAL OF THE USER
    videosSearch = VideosSearch(search_title, limit = 2)
    for vid in videosSearch.result()['result']:
        vid_lower = normalize_text(vid['title'])
        print(vid['title'])
        if success == False:
            if all(item in vid_lower for item in search_queries_1):
                if any(item in vid_lower for item in search_queries_2):
                    #vid_titles.append([vid['title'],vid['link']])
                    download_audio_from_youtube(dali_id,vid['link'],save_dir)
                    success=True
                    break
                elif all(item not in vid_lower for item in search_queries_3):   
                   # vid_titles.append([vid['title'],vid['link']])
                    download_audio_from_youtube(dali_id,vid['link'],save_dir)
                    success=True  
                    break
    
    return success

# %% [markdown]
#   - Main download loop below:

# %%
retrieved =[]
failed = []

for row in data.iterrows():
    
    success = False
    print(row[0])
    # PARSE SONG ID INFO TO BE USED FOR SEARCHING ON YOUTUBE
    
    success = retrieve_audio_for_dali_test(row,SAVE_DIR,success)
    
    if success == True:
        
        retrieved.append(row[0])
        print('Retrieval of ' + row[1]['SONG_TITLE'] + ' - ' + row[1]['ARTIST'] + ' is successful.')

    if success == False:
        print('Could not retrieve the audio for ' + row[0] +' due to search queries are not present in the video title!')
        failed.append(row[0])
        #print('\n')
# Out:
# 44a2455abc0e4fb397a396d2cd1ebeb9
# A1 - Caught in the Middle
# [youtube] qz57Ucb02yo: Downloading webpage
# [download] ./audio/44a2455abc0e4fb397a396d2cd1ebeb9.mp3 has already been downloaded
# [download] 100% of 3.20MiB
# [ffmpeg] Post-process file ./audio/44a2455abc0e4fb397a396d2cd1ebeb9.mp3 exists, skipping
# Retrieval of Caught In The Middle - A1 is successful.
# 15d6e9e88ced41dfbff38ba2f3e1d885
# Ace of Base - All for You (Official Music Video)
# [youtube] Vg0zSGVNjfo: Downloading webpage
# [download] ./audio/15d6e9e88ced41dfbff38ba2f3e1d885.mp3 has already been downloaded
# [download] 100% of 3.37MiB
# [ffmpeg] Post-process file ./audio/15d6e9e88ced41dfbff38ba2f3e1d885.mp3 exists, skipping
# Retrieval of All For You - Ace Of Base is successful.
# a59e44a4c910443a87f068b177200fdc
# Ace of Base - Life Is a Flower (Official Music Video)
# [youtube] sdc_6YvJfFo: Downloading webpage
# [download] ./audio/a59e44a4c910443a87f068b177200fdc.mp3 has already been downloaded
# [download] 100% of 3.32MiB
# [ffmpeg] Post-process file ./audio/a59e44a4c910443a87f068b177200fdc.mp3 exists, skipping
# Retrieval of Life Is A Flower - Ace Of Base is successful.
# ae91bcda73944695b7756ddc066c3e02
# Ace of Base - Beautiful Life (Official Music Video)
# [youtube] wh-07BzfgYY: Downloading webpage
# [download] ./audio/ae91bcda73944695b7756ddc066c3e02.mp3 has already been downloaded
# [download] 100% of 3.43MiB
# [ffmpeg] Correcting container in "./audio/ae91bcda73944695b7756ddc066c3e02.mp3"
# [ffmpeg] Post-process file ./audio/ae91bcda73944695b7756ddc066c3e02.mp3 exists, skipping
# Retrieval of Beautiful Life - Ace Of Base is successful.
# d6e3cf403653490f8366bf77cbc0f186
# Adema - Unstable (Video)
# [youtube] 1IsBbK1PhtE: Downloading webpage
# [download] ./audio/d6e3cf403653490f8366bf77cbc0f186.mp3 has already been downloaded
# [download] 100% of 2.93MiB
# [ffmpeg] Correcting container in "./audio/d6e3cf403653490f8366bf77cbc0f186.mp3"
# [ffmpeg] Post-process file ./audio/d6e3cf403653490f8366bf77cbc0f186.mp3 exists, skipping
# Retrieval of Unstable - Adema is successful.
# 7a1642003f574713a6e25e5ee549fce6
# AGNETHA FÄLTSKOG "Walk in the room" (Official video)
# Agnetha Faltskog   When You Walk In The Room
# [youtube] 3CqTuU3E8GI: Downloading webpage
# [download] ./audio/7a1642003f574713a6e25e5ee549fce6.mp3 has already been downloaded
# [download] 100% of 3.39MiB
# [ffmpeg] Post-process file ./audio/7a1642003f574713a6e25e5ee549fce6.mp3 exists, skipping
# Retrieval of When You Walk In The Room - Agnetha Faltskog is successful.
# 8eb15ad6d17f41b68009fe3848930dee
# Akcent - Love Stoned (Official Video)
# [youtube] 7I9sqR05uYc: Downloading webpage
# [download] ./audio/8eb15ad6d17f41b68009fe3848930dee.mp3 has already been downloaded
# [download] 100% of 4.10MiB
# [ffmpeg] Post-process file ./audio/8eb15ad6d17f41b68009fe3848930dee.mp3 exists, skipping
# Retrieval of Love Stoned - Akcent is successful.
# b63d71b7ec6b4c5e9f53a87f83fcd73e
# Alexandra Burke- Hallelujah lyrics
# [youtube] W-kLDzUmlls: Downloading webpage
# [download] ./audio/b63d71b7ec6b4c5e9f53a87f83fcd73e.mp3 has already been downloaded
# [download] 100% of 3.44MiB
# [ffmpeg] Post-process file ./audio/b63d71b7ec6b4c5e9f53a87f83fcd73e.mp3 exists, skipping
# Retrieval of Hallelujah - Alexandra Burke is successful.
# ac0279efad294261b4c7dc0b86eaaec5
# Alex Gaudino feat. Crystal Waters - Destination Calabria [Explicit Version] [Official Video]
# [youtube] Kq4OtRsdXls: Downloading webpage
# [download] ./audio/ac0279efad294261b4c7dc0b86eaaec5.mp3 has already been downloaded
# [download] 100% of 2.82MiB
# [ffmpeg] Correcting container in "./audio/ac0279efad294261b4c7dc0b86eaaec5.mp3"
# [ffmpeg] Post-process file ./audio/ac0279efad294261b4c7dc0b86eaaec5.mp3 exists, skipping
# Retrieval of Destination Calabria - Alex Gaudino is successful.
# 1478242633aa4628aa9a88ca6f54130a
# No More Mr. Nice Guy
# Alice Cooper - No More Mr. Nice Guy (from Alice Cooper: Trashes The World) [Official Video]
# [youtube] KN6ngThqMEs: Downloading webpage
# [download] ./audio/1478242633aa4628aa9a88ca6f54130a.mp3 has already been downloaded
# [download] 100% of 2.86MiB
# [ffmpeg] Correcting container in "./audio/1478242633aa4628aa9a88ca6f54130a.mp3"
# [ffmpeg] Post-process file ./audio/1478242633aa4628aa9a88ca6f54130a.mp3 exists, skipping
# Retrieval of No More Mr. Nice Guy - Alice Cooper is successful.
# b60f5426792642f9a9c59717d0ec3b23
# Aloe Blacc - Loving You Is Killing Me (official video)
# [youtube] w-iIzDtcXiM: Downloading webpage
# [download] ./audio/b60f5426792642f9a9c59717d0ec3b23.mp3 has already been downloaded
# Retrieval of Oh Boy! - Buddy Holly is successful.
# d9d748696b5949d993bdca21a49a4ebe
# Buddy Holly - Peggy Sue HQ
# [youtube] OUesbTObC9A: Downloading webpage
# [download] ./audio/d9d748696b5949d993bdca21a49a4ebe.mp3 has already been downloaded
# [download] 100% of 2.39MiB
# [ffmpeg] Correcting container in "./audio/d9d748696b5949d993bdca21a49a4ebe.mp3"
# [ffmpeg] Post-process file ./audio/d9d748696b5949d993bdca21a49a4ebe.mp3 exists, skipping
# Retrieval of Peggy Sue - Buddy Holly is successful.
# f97b5ce17a7645cfb9e90f365c622d44
# Buddy Holly - Everyday
# [youtube] GMezwtB1oCU: Downloading webpage
# [download] ./audio/f97b5ce17a7645cfb9e90f365c622d44.mp3 has already been downloaded
# [download] 100% of 2.01MiB
# [ffmpeg] Post-process file ./audio/f97b5ce17a7645cfb9e90f365c622d44.mp3 exists, skipping
# Retrieval of Everyday - Buddy Holly is successful.
# 0cf0e93e4baa4e4fb9ce69b3555ff9a3
# Carly Simon - You're So Vain
# [youtube] mQZmCJUSC6g: Downloading webpage
# [download] ./audio/0cf0e93e4baa4e4fb9ce69b3555ff9a3.mp3 has already been downloaded
# [download] 100% of 4.34MiB
# [ffmpeg] Correcting container in "./audio/0cf0e93e4baa4e4fb9ce69b3555ff9a3.mp3"
# [ffmpeg] Post-process file ./audio/0cf0e93e4baa4e4fb9ce69b3555ff9a3.mp3 exists, skipping
# Retrieval of You're So Vain - Carly Simon is successful.
# 7357de99882d49cb9a0564a8ce4d60f4
# Carly Simon - Coming Around Again (Official Video)
# [youtube] c0A7jAVDPJU: Downloading webpage
# [download] ./audio/7357de99882d49cb9a0564a8ce4d60f4.mp3 has already been downloaded
# [download] 100% of 3.40MiB
# [ffmpeg] Post-process file ./audio/7357de99882d49cb9a0564a8ce4d60f4.mp3 exists, skipping
# Retrieval of Coming Around Again - Carly Simon is successful.
# aebd6dbeee764e1586dcadef42a51c66
# Let The River Run - Carly Simon
# [youtube] cv-0mmVnxPA: Downloading webpage
# [download] ./audio/aebd6dbeee764e1586dcadef42a51c66.mp3 has already been downloaded
# [download] 100% of 3.23MiB
# [ffmpeg] Correcting container in "./audio/aebd6dbeee764e1586dcadef42a51c66.mp3"
# [ffmpeg] Post-process file ./audio/aebd6dbeee764e1586dcadef42a51c66.mp3 exists, skipping
# Retrieval of Let The River Run - Carly Simon is successful.
# 7dba05a37342438a9ae829fd2939c50d
# Cascada runaway--lyrics
# [youtube] BqQ0dtrw0Kw: Downloading webpage
# [download] ./audio/7dba05a37342438a9ae829fd2939c50d.mp3 has already been downloaded
# [download] 100% of 3.22MiB
# [ffmpeg] Post-process file ./audio/7dba05a37342438a9ae829fd2939c50d.mp3 exists, skipping
# Retrieval of Runaway - Cascada is successful.
# 874ff998bef04d939b8b21f7434abacd
# Cascada - Bad Boy (lyrics)
# [youtube] SoYLSOcgTeg: Downloading webpage
# [download] ./audio/874ff998bef04d939b8b21f7434abacd.mp3 has already been downloaded
# [download] 100% of 2.91MiB
# [ffmpeg] Correcting container in "./audio/874ff998bef04d939b8b21f7434abacd.mp3"
# [ffmpeg] Post-process file ./audio/874ff998bef04d939b8b21f7434abacd.mp3 exists, skipping
# Retrieval of Bad Boy - Cascada is successful.
# 8b93024dfc974fe39b359a85db00be53
# Cascada - Everytime I Hear Your Name
# [youtube] q5KtM23jBME: Downloading webpage
# [download] ./audio/8b93024dfc974fe39b359a85db00be53.mp3 has already been downloaded
# [download] 100% of 3.01MiB
# [ffmpeg] Post-process file ./audio/8b93024dfc974fe39b359a85db00be53.mp3 exists, skipping
# Retrieval of Everytime I Hear Your Name - Cascada is successful.
# 9a2d29267c484d75af6b19b14d69cab9
# Cher - The Shoop Shoop Song (It's In His Kiss) [Official Music Video]
# [youtube] yCpKQjqb8Y4: Downloading webpage
# [download] ./audio/9a2d29267c484d75af6b19b14d69cab9.mp3 has already been downloaded
# [download] 100% of 2.62MiB
# [ffmpeg] Correcting container in "./audio/9a2d29267c484d75af6b19b14d69cab9.mp3"
# [ffmpeg] Post-process file ./audio/9a2d29267c484d75af6b19b14d69cab9.mp3 exists, skipping
# Retrieval of The Shoop Shoop Song (It's In His Kiss) - Cher is successful.
# c69d9213f91a40349ce570c6c8d9fdc6
# Cher Lloyd - With Ur Love ft. Mike Posner
# [youtube] axpO86pGHAM: Downloading webpage
# [download] ./audio/c69d9213f91a40349ce570c6c8d9fdc6.mp3 has already been downloaded
# [download] 100% of 3.53MiB
# [ffmpeg] Correcting container in "./audio/c69d9213f91a40349ce570c6c8d9fdc6.mp3"
# [ffmpeg] Post-process file ./audio/c69d9213f91a40349ce570c6c8d9fdc6.mp3 exists, skipping
# Retrieval of With Ur Love - Cher Lloyd is successful.
# f45833d95ffc48a092874ed9c01bcad8
# Cher Lloyd - Swagger Jagger
# [youtube] sdbyG2MrBHk: Downloading webpage
# [download] ./audio/f45833d95ffc48a092874ed9c01bcad8.mp3 has already been downloaded
# [download] 100% of 3.23MiB
# [ffmpeg] Post-process file ./audio/f45833d95ffc48a092874ed9c01bcad8.mp3 exists, skipping
# Retrieval of Swagger Jagger - Cher Lloyd is successful.
# 9eb55eeb476e48a79b41876fdcab6712
# Chicago - Hard To Say I'm Sorry/Get Away (Official Audio)
# [youtube] EORSLz0_BRU: Downloading webpage
# [download] ./audio/9eb55eeb476e48a79b41876fdcab6712.mp3 has already been downloaded
# [download] 100% of 4.87MiB
# [ffmpeg] Post-process file ./audio/9eb55eeb476e48a79b41876fdcab6712.mp3 exists, skipping
# Retrieval of Hard To Say I'm Sorry/Get Away - Chicago is successful.
# a9dbecf01e344031a22643a10524f8fb
# Chicago - Look Away (Official Music Video)
# [youtube] 2uKLTtVqQpE: Downloading webpage
# [download] ./audio/a9dbecf01e344031a22643a10524f8fb.mp3 has already been downloaded
# [download] 100% of 3.80MiB
# [ffmpeg] Post-process file ./audio/a9dbecf01e344031a22643a10524f8fb.mp3 exists, skipping
# Retrieval of Look Away - Chicago is successful.
# 452037efa1284176b7aa7b80a05afa95
iB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/e6f7c7bb2d3a465f8fb495038778c28c.mp3 exists, skipping
# Retrieval of Thinking Out Loud - Ed Sheeran is successful.
# 134fa78a3d4a462299db018f0444ce26
# Electric Light Orchestra - Hold On Tight (Official Video)
# [youtube] UkekqVPIc2M: Downloading webpage
# [download] Destination: ./audio/134fa78a3d4a462299db018f0444ce26.mp3
# [download] 100% of 2.85MiB in 00:0084MiB/s ETA 00:003
# [ffmpeg] Correcting container in "./audio/134fa78a3d4a462299db018f0444ce26.mp3"
# [ffmpeg] Post-process file ./audio/134fa78a3d4a462299db018f0444ce26.mp3 exists, skipping
# Retrieval of Hold On Tight - Electric Light Orchestra is successful.
# 97349fc35f414864ab080f7c78e3f51e
# The Silk Dilemma
# Elvenking - The Silk Dilemma
# [youtube] 3bhMj_xEONg: Downloading webpage
# [download] Destination: ./audio/97349fc35f414864ab080f7c78e3f51e.mp3
# [download] 100% of 4.03MiB in 00:0134MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio/97349fc35f414864ab080f7c78e3f51e.mp3 exists, skipping
# Retrieval of The Silk Dilemma - Elvenking is successful.
# 647553dfb24b4f63832722217cbc1857
# Elvis Costello 'She'
# [youtube] O040xuq2FR0: Downloading webpage
# [download] Destination: ./audio/647553dfb24b4f63832722217cbc1857.mp3
# [download] 100% of 3.00MiB in 00:0038MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/647553dfb24b4f63832722217cbc1857.mp3 exists, skipping
# Retrieval of She - Elvis Costello is successful.
# 11a0f31e81094120bf8439c597b6c7d8
# Eric Saade - Break of Dawn [Official Music Video]
# [youtube] k55OamTp85s: Downloading webpage
# [download] Destination: ./audio/11a0f31e81094120bf8439c597b6c7d8.mp3
# [download] 100% of 4.09MiB in 00:0038MiB/s ETA 00:006
# [ffmpeg] Post-process file ./audio/11a0f31e81094120bf8439c597b6c7d8.mp3 exists, skipping
# Retrieval of Break Of Dawn - Eric Saade is successful.
# 74ba3bdc8c2f422a9e986a0522b0e6c5
# Evermore - It's Too Late (Ride On)
# [youtube] bBTN93Ue8jI: Downloading webpage
# [download] Destination: ./audio/74ba3bdc8c2f422a9e986a0522b0e6c5.mp3
# [download] 100% of 3.67MiB in 00:0012MiB/s ETA 00:0003
# [ffmpeg] Correcting container in "./audio/74ba3bdc8c2f422a9e986a0522b0e6c5.mp3"
# [ffmpeg] Post-process file ./audio/74ba3bdc8c2f422a9e986a0522b0e6c5.mp3 exists, skipping
# Retrieval of It's Too Late - Evermore is successful.
# afa903f29d06489189a6f77b4d1cda93
# Sad Exchange
# Finger Eleven - Sad Exchange Lyrics
# [youtube] yr4ySv5jVeY: Downloading webpage
# [download] Destination: ./audio/afa903f29d06489189a6f77b4d1cda93.mp3
# [download] 100% of 3.03MiB in 00:0156MiB/s ETA 00:003
# [ffmpeg] Correcting container in "./audio/afa903f29d06489189a6f77b4d1cda93.mp3"
# [ffmpeg] Post-process file ./audio/afa903f29d06489189a6f77b4d1cda93.mp3 exists, skipping
# Retrieval of Sad Exchange - Finger Eleven is successful.
# 3179c8442b78428380553a94f0f70603
# Fischer-Z - Marliese
# [youtube] j6TAevvtFfE: Downloading webpage
# [download] Destination: ./audio/3179c8442b78428380553a94f0f70603.mp3
# [download] 100% of 3.56MiB in 00:0007MiB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/3179c8442b78428380553a94f0f70603.mp3 exists, skipping
# Retrieval of Marliese - Fischer-Z is successful.
# 0091064bdc72469ca7096d3a0db74562
# Five for Fighting - 100 Years (Official Music Video)
# [youtube] tR-qQcNT_fY: Downloading webpage
# [download] Destination: ./audio/0091064bdc72469ca7096d3a0db74562.mp3
# [download] 100% of 4.30MiB in 00:0006MiB/s ETA 00:008
# [ffmpeg] Post-process file ./audio/0091064bdc72469ca7096d3a0db74562.mp3 exists, skipping
# Retrieval of 100 Years - Five For Fighting is successful.
# 1d257d06c8bb491ca1934516fd110b58
# Foals - Cassius (OFFICIAL VIDEO)
# [youtube] ARu_XbUg8bo: Downloading webpage
# [download] Destination: ./audio/1d257d06c8bb491ca1934516fd110b58.mp3
# [download] 100% of 3.62MiB in 00:0035MiB/s ETA 00:006
# [ffmpeg] Correcting container in "./audio/1d257d06c8bb491ca1934516fd110b58.mp3"
# [ffmpeg] Post-process file ./audio/1d257d06c8bb491ca1934516fd110b58.mp3 exists, skipping
# Retrieval of Cassius - Foals is successful.
# 2fa1a8f3015d42f387b78b4f3601acd4
# Fort Atlantic - Let Your Heart Hold Fast Official Lyric Video
# [youtube] kBqWtdMpies: Downloading webpage
# [download] Destination: ./audio/2fa1a8f3015d42f387b78b4f3601acd4.mp3
# [download] 100% of 3.67MiB in 00:0058MiB/s ETA 00:008
# [ffmpeg] Post-process file ./audio/2fa1a8f3015d42f387b78b4f3601acd4.mp3 exists, skipping
# Retrieval of Let Your Heart Hold Fast - Fort Atlantic is successful.
# 568ca0f42dda4d65af3ab101931b190f
# Fun.: We Are Young ft. Janelle Monáe [OFFICIAL VIDEO]
# [youtube] Sv6dMFF_yts: Downloading webpage
# [download] Destination: ./audio/568ca0f42dda4d65af3ab101931b190f.mp3
# [download] 100% of 3.89MiB in 00:0093MiB/s ETA 00:004
# [ffmpeg] Correcting container in "./audio/568ca0f42dda4d65af3ab101931b190f.mp3"
# [ffmpeg] Post-process file ./audio/568ca0f42dda4d65af3ab101931b190f.mp3 exists, skipping
# Retrieval of We Are Young - Fun. is successful.
# 5ee5d7662fcb42a683f64490dec96dcf
# Gaitana - Be My Guest - Live - Grand Final - 2012 Eurovision Song Contest
# [youtube] sLsTn_li5d8: Downloading webpage
# [download] Destination: ./audio/5ee5d7662fcb42a683f64490dec96dcf.mp3
# [download] 100% of 3.41MiB in 00:0081MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/5ee5d7662fcb42a683f64490dec96dcf.mp3 exists, skipping
# Retrieval of Be My Guest - Gaitana is successful.
# 215a11a438ce4963be16212d71d68aaa
# Garbage - I Think I'm Paranoid (Official Video)
# [youtube] ypr18UmxOas: Downloading webpage
# [download] Destination: ./audio/215a11a438ce4963be16212d71d68aaa.mp3
# [download] 100% of 3.36MiB in 00:0078MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/215a11a438ce4963be16212d71d68aaa.mp3 exists, skipping
# Retrieval of I Think I'm Paranoid - Garbage is successful.
# 38bc6e2c27334a9b8af3a7e1244cbfc1
# Garbage - When I Grow Up (Big Daddy Version)
# [youtube] _uDiGAr_WKs: Downloading webpage
# [download] Destination: ./audio/38bc6e2c27334a9b8af3a7e1244cbfc1.mp3
# [download] 100% of 3.11MiB in 00:0058MiB/s ETA 00:003
# [ffmpeg] Correcting container in "./audio/38bc6e2c27334a9b8af3a7e1244cbfc1.mp3"
# [ffmpeg] Post-process file ./audio/38bc6e2c27334a9b8af3a7e1244cbfc1.mp3 exists, skipping
# Retrieval of When I Grow Up - Garbage is successful.
# 749a37373ef447949d520add48f55852
# Garbage - The World Is Not Enough
# [youtube] eI7KxEerCYo: Downloading webpage
# [download] Destination: ./audio/749a37373ef447949d520add48f55852.mp3
# [download] 100% of 3.67MiB in 00:0063MiB/s ETA 00:004
# [ffmpeg] Correcting container in "./audio/749a37373ef447949d520add48f55852.mp3"
# [ffmpeg] Post-process file ./audio/749a37373ef447949d520add48f55852.mp3 exists, skipping
# Retrieval of The World Is Not Enough - Garbage is successful.
# 5d6ce8b5378f41c6a9906d905c0d3c4f
# Gareth Gates - Anyone Of Us (Stupid Mistake)
# [youtube] iFa6I9KN63Q: Downloading webpage
# [download] Destination: ./audio/5d6ce8b5378f41c6a9906d905c0d3c4f.mp3
# [download] 100% of 3.66MiB in 00:0091MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio/5d6ce8b5378f41c6a9906d905c0d3c4f.mp3 exists, skipping
# Retrieval of One Of Us - Gareth Gates is successful.
# ff348b1ede1043d8a1ab033b326f8056
# Gary Go - Wonderful
# [youtube] a28s_wyqkyc: Downloading webpage
# [download] Destination: ./audio/ff348b1ede1043d8a1ab033b326f8056.mp3
# [download] 100% of 3.56MiB in 00:0009MiB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/ff348b1ede1043d8a1ab033b326f8056.mp3 exists, skipping
# Retrieval of Wonderful - Gary Go is successful.
# 607bb216fd9c49f88604be23bb3bc87c
# Gary Moore - Still Got The Blues (Live)
# [youtube] 4O_YMLDvvnw: Downloading webpage
# [download] Destination: ./audio/607bb216fd9c49f88604be23bb3bc87c.mp3
# [download] 100% of 6.59MiB in 00:0024MiB/s ETA 00:007
# [ffmpeg] Post-process file ./audio/607bb216fd9c49f88604be23bb3bc87c.mp3 exists, skipping
# Retrieval of Still Got The Blues - Gary Moore is successful.
# ff33ea7be69e46e4bf154c1d6f3ae45b
# Gary Moore - Always Gonna Love You [HD]
# [youtube] c0gg4zY0oZ0: Downloading webpage
# [download] Destination: ./audio/ff33ea7be69e46e4bf154c1d6f3ae45b.mp3
# [download] 100% of 3.69MiB in 00:4483KiB/s ETA 00:002
# [ffmpeg] Post-process file ./audio/ff33ea7be69e46e4bf154c1d6f3ae45b.mp3 exists, skipping
# Retrieval of Always Gonna Love You - Gary Moore is successful.
# 60725a5ecd6f4605abac479d3cacbc98
# Genesis - Cuckoo Cocoon
# [youtube] 0AHqY-m6RZY: Downloading webpage
# [download] Destination: ./audio/60725a5ecd6f4605abac479d3cacbc98.mp3
# [download] 100% of 2.21MiB in 00:0090MiB/s ETA 00:002
# [ffmpeg] Post-process file ./audio/60725a5ecd6f4605abac479d3cacbc98.mp3 exists, skipping
# Retrieval of Cuckoo Cocoon - Genesis is successful.
# 0ab34ce9fa6a4da38a1ec894f0e3a1f4
# Gentleman - Dem Gone (MTV Unplugged)
# [youtube] cIrDqBSUrYw: Downloading webpage
# [download] Destination: ./audio/0ab34ce9fa6a4da38a1ec894f0e3a1f4.mp3
# [download] 100% of 3.96MiB in 00:0055MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio
# [ffmpeg] Correcting container in "./audio/028d81449c0b46838a873d69729e82de.mp3"
# [ffmpeg] Post-process file ./audio/028d81449c0b46838a873d69729e82de.mp3 exists, skipping
# Retrieval of Seasons In The Sun - Terry Jacks is successful.
# 80ea09d8563b495aa5e651c2b4b66a8c
# Texas Guitar Song
# [youtube] N7LzQ4Uofso: Downloading webpage
# [download] Destination: ./audio/80ea09d8563b495aa5e651c2b4b66a8c.mp3
# [download] 100% of 3.58MiB in 00:5417KiB/s ETA 00:005
# [ffmpeg] Correcting container in "./audio/80ea09d8563b495aa5e651c2b4b66a8c.mp3"
# [ffmpeg] Post-process file ./audio/80ea09d8563b495aa5e651c2b4b66a8c.mp3 exists, skipping
# Retrieval of Guitar Song - Texas is successful.
# 3f4cc4b9de2545d78dffaeb8a30aff12
# The 411 - Dumb (Video)
# [youtube] OU4kws6n700: Downloading webpage
# [download] Destination: ./audio/3f4cc4b9de2545d78dffaeb8a30aff12.mp3
# [download] 100% of 2.72MiB in 00:0021MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/3f4cc4b9de2545d78dffaeb8a30aff12.mp3 exists, skipping
# Retrieval of Dumb - The 411 is successful.
# f2c034b68e5b4c889b69e55008c3fe0b
# Thea Garrett - My Dream (Malta) Live 2010 Eurovision Song Contest
# [youtube] iwgF3TC2Kj0: Downloading webpage
# [download] Destination: ./audio/f2c034b68e5b4c889b69e55008c3fe0b.mp3
# [download] 100% of 3.17MiB in 00:0160MiB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/f2c034b68e5b4c889b69e55008c3fe0b.mp3 exists, skipping
# Retrieval of My Dream - Thea Garrett is successful.
# 140c5c32888d4f27af3e4fd3bf5b7250
# The Bangles - Eternal Flame
# [youtube] PSoOFn3wQV4: Downloading webpage
# [download] Destination: ./audio/140c5c32888d4f27af3e4fd3bf5b7250.mp3
# [download] 100% of 3.90MiB in 00:0085MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio/140c5c32888d4f27af3e4fd3bf5b7250.mp3 exists, skipping
# Retrieval of Eternal Flame - The Bangles is successful.
# af358461b75342a8a87f92912634a7d8
# The Bangles - Manic Monday
# [youtube] SsmVgoXDq2w: Downloading webpage
# [download] Destination: ./audio/af358461b75342a8a87f92912634a7d8.mp3
# [download] 100% of 2.96MiB in 00:0037MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/af358461b75342a8a87f92912634a7d8.mp3 exists, skipping
# Retrieval of Manic Monday - The Bangles is successful.
# 92b9ccf81fee4c7f90ee1f56a4bb35db
# The Beach Boys-Don't Worry Baby
# [youtube] X9E1by7PocE: Downloading webpage
# [download] Destination: ./audio/92b9ccf81fee4c7f90ee1f56a4bb35db.mp3
# [download] 100% of 2.56MiB in 00:0082MiB/s ETA 00:002
# [ffmpeg] Correcting container in "./audio/92b9ccf81fee4c7f90ee1f56a4bb35db.mp3"
# [ffmpeg] Post-process file ./audio/92b9ccf81fee4c7f90ee1f56a4bb35db.mp3 exists, skipping
# Retrieval of Don't Worry Baby - The Beach Boys is successful.
# 05d128a31ad64acca530cd8f4125a423
# The Cat Empire - Feeling's Gone (Official Video)
# [youtube] ZLGIz8Pi714: Downloading webpage
# [download] Destination: ./audio/05d128a31ad64acca530cd8f4125a423.mp3
# [download] 100% of 2.49MiB in 00:0064MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/05d128a31ad64acca530cd8f4125a423.mp3 exists, skipping
# Retrieval of Feeling's Gone - The Cat Empire is successful.
# 57a743bbbc7c472788d258f977c11cee
# The Cult - Wild Flower
# [youtube] _NxrphVL7bQ: Downloading webpage
# [download] Destination: ./audio/57a743bbbc7c472788d258f977c11cee.mp3
# [download] 100% of 3.37MiB in 00:0020MiB/s ETA 00:0003
# [ffmpeg] Correcting container in "./audio/57a743bbbc7c472788d258f977c11cee.mp3"
# [ffmpeg] Post-process file ./audio/57a743bbbc7c472788d258f977c11cee.mp3 exists, skipping
# Retrieval of Wild Flower - The Cult is successful.
# 463f5b79b3f1459887c96c368b16c9c0
# The Cure - Close To Me (Official Video)
# [youtube] BjvfIJstWeg: Downloading webpage
# [download] Destination: ./audio/463f5b79b3f1459887c96c368b16c9c0.mp3
# [download] 100% of 3.70MiB in 00:0072MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio/463f5b79b3f1459887c96c368b16c9c0.mp3 exists, skipping
# Retrieval of Close To Me - The Cure is successful.
# 4789ae2083ac430b8628beb5f1fd6424
# The Cure - In Between Days (Official Video)
# [youtube] scif2vfg1ug: Downloading webpage
# [download] Destination: ./audio/4789ae2083ac430b8628beb5f1fd6424.mp3
# [download] 100% of 2.92MiB in 00:0048MiB/s ETA 00:002
# [ffmpeg] Correcting container in "./audio/4789ae2083ac430b8628beb5f1fd6424.mp3"
# [ffmpeg] Post-process file ./audio/4789ae2083ac430b8628beb5f1fd6424.mp3 exists, skipping
# Retrieval of In Between Days - The Cure is successful.
# ea239f890da24d08bf2fcf41ad8b883b
# The Cure - High
# [youtube] w9xXCK28wDU: Downloading webpage
# [download] Destination: ./audio/ea239f890da24d08bf2fcf41ad8b883b.mp3
# [download] 100% of 3.51MiB in 00:0037MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio/ea239f890da24d08bf2fcf41ad8b883b.mp3 exists, skipping
# Retrieval of High - The Cure is successful.
# 6241722644184050bb1a04a840701e54
# The Gathering - Rescue Me
# [youtube] 0pHiYqJCpNw: Downloading webpage
# [download] Destination: ./audio/6241722644184050bb1a04a840701e54.mp3
# [download] 100% of 6.00MiB in 00:0055MiB/s ETA 00:007
# [ffmpeg] Post-process file ./audio/6241722644184050bb1a04a840701e54.mp3 exists, skipping
# Retrieval of Rescue Me - The Gathering is successful.
# a1f95acf37684dbda26a0fd9d7e99f29
# The Gathering - You Learn About It (Video)
# [youtube] yq9GpAWF6RA: Downloading webpage
# [download] Destination: ./audio/a1f95acf37684dbda26a0fd9d7e99f29.mp3
# [download] 100% of 3.58MiB in 00:0023MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio/a1f95acf37684dbda26a0fd9d7e99f29.mp3 exists, skipping
# Retrieval of You Learn About It - The Gathering is successful.
# dc0cd0d4ec64447e894540fe4a0a01f5
# Pale Traces
# The Gathering - Pale Traces (Subtitulada)
# [youtube] aZuhVO7gwlE: Downloading webpage
# [download] Destination: ./audio/dc0cd0d4ec64447e894540fe4a0a01f5.mp3
# [download] 100% of 7.58MiB in 00:0164MiB/s ETA 00:007
# [ffmpeg] Post-process file ./audio/dc0cd0d4ec64447e894540fe4a0a01f5.mp3 exists, skipping
# Retrieval of Pale Traces - The Gathering is successful.
# d1a18dd66ef244418853f87a5c1dcd78
# The Lumineers - Ho Hey (Official Video)
# [youtube] zvCBSSwgtg4: Downloading webpage
# [download] Destination: ./audio/d1a18dd66ef244418853f87a5c1dcd78.mp3
# [download] 100% of 2.49MiB in 00:0072MiB/s ETA 00:0002
# [ffmpeg] Correcting container in "./audio/d1a18dd66ef244418853f87a5c1dcd78.mp3"
# [ffmpeg] Post-process file ./audio/d1a18dd66ef244418853f87a5c1dcd78.mp3 exists, skipping
# Retrieval of Ho Hey - The Lumineers is successful.
# ae45d924a10e4b10ad80d43497ebe9be
# Pointer Sisters - Fire
# [youtube] K9S5EZgIJck: Downloading webpage
# [download] Destination: ./audio/ae45d924a10e4b10ad80d43497ebe9be.mp3
# [download] 100% of 3.36MiB in 00:0087MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/ae45d924a10e4b10ad80d43497ebe9be.mp3 exists, skipping
# Retrieval of Fire - Pointer Sisters is successful.
# 6f3d8aad9990437c91d3f9d77cd51f11
# The Roots - The Seed (2.0) (Official Music Video) ft. Cody ChesnuTT
# [youtube] ojC0mg2hJCc: Downloading webpage
# [download] Destination: ./audio/6f3d8aad9990437c91d3f9d77cd51f11.mp3
# [download] 100% of 3.95MiB in 00:0209MiB/s ETA 00:006
# [ffmpeg] Correcting container in "./audio/6f3d8aad9990437c91d3f9d77cd51f11.mp3"
# [ffmpeg] Post-process file ./audio/6f3d8aad9990437c91d3f9d77cd51f11.mp3 exists, skipping
# Retrieval of The Seed - The Roots is successful.
# 97c9e2b0ffa34f259e21d5ec0752faf6
# Snoopy's Christmas
# Snoopy's Christmas -- Royal Guardsmen
# [youtube] 0-hWZGIWe_U: Downloading webpage
# [download] Destination: ./audio/97c9e2b0ffa34f259e21d5ec0752faf6.mp3
# [download] 100% of 3.11MiB in 00:0429MiB/s ETA 00:002
# [ffmpeg] Post-process file ./audio/97c9e2b0ffa34f259e21d5ec0752faf6.mp3 exists, skipping
# Retrieval of Snoopy's Christmas - Royal Guardsmen is successful.
# 06e8322a90954a028762888dfe3e70cf
# The Saturdays - My Heart Takes Over
# [youtube] DgmoYgpMNX8: Downloading webpage
# [download] Destination: ./audio/06e8322a90954a028762888dfe3e70cf.mp3
# [download] 100% of 3.48MiB in 00:0302MiB/s ETA 00:000
# [ffmpeg] Correcting container in "./audio/06e8322a90954a028762888dfe3e70cf.mp3"
# [ffmpeg] Post-process file ./audio/06e8322a90954a028762888dfe3e70cf.mp3 exists, skipping
# Retrieval of My Heart Takes Over - The Saturdays is successful.
# 6b4369a6c8704cc4936368fc85dbfa5b
# The Script - We Cry (Official Video)
# [youtube] UzY8LA4rxxM: Downloading webpage
# [download] Destination: ./audio/6b4369a6c8704cc4936368fc85dbfa5b.mp3
# [download] 100% of 3.47MiB in 00:0172MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio/6b4369a6c8704cc4936368fc85dbfa5b.mp3 exists, skipping
# Retrieval of We Cry - The Script is successful.
# 2bdce213821c491293061bbd4a5b6ac1
# The Smashing Pumpkins - Ava Adore (Official Music Video)
# [youtube] 9uWwvQKGjLI: Downloading webpage
# [download] Destination: ./audio/2bdce213821c491293061bbd4a5b6ac1.mp3
# [download] 100% of 4.00MiB in 00:0401MiB/s ETA 00:001
# [ffmpeg] Correcting container in "./audio/2bdce213821c491293061bbd4a5b6ac1.mp3"
# [ffmpeg] Post-process file ./audio/2bdce213821c491293061bbd4a5b6ac1.mp3 exists, skipping
# Retrieval of Ava Adore - The Smashing Pumpkins is successful.
# b48c72da216e40bbb290ce726e926534
# The Smashing Pumpkins - Thirty-Three (Official Music Video)
# [youtube] AYSbztCCTlA: Downloading webpage
# [download] Destination: ./audio/b48c72da216e40bbb290ce726e926534.mp3
# [download] 100% of 4.10MiB in 00:0167MiB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/b48c72da216e40bbb290ce726e926534.mp3 exists, skipping
# Retrieval of Thirty-Three - The Smashing Pumpkins is successful.
# de1c0929af0e4026b705b46b88aead33
# Captain Feathersword Fell Asleep On His Pirate Ship (Quack Quack)
# The Wiggles: Captain Feathersword Fell Asleep On His Pirate Ship (Quack Quack) (1998)
# [youtube] tWWVSHw5Tz0: Downloading webpage
# [youtube] tWWVSHw5Tz0: Downloading MPD manifest
# [download] Destination: ./audio/de1c0929af0e4026b705b46b88aead33.mp3
# [download] 100% of 1.82MiB in 00:0178MiB/s ETA 00:001
# [ffmpeg] Correcting container in "./audio/de1c0929af0e4026b705b46b88aead33.mp3"
# [ffmpeg] Post-process file ./audio/de1c0929af0e4026b705b46b88aead33.mp3 exists, skipping
# Retrieval of Captain Feathersword Fell Asleep On His Pirate Ship (Quack Quack) - The Wiggles is successful.
# adeeffbf18cc4c6cb3de6af56cb407cd
# Tom Waits  Ol '55
# Tom Waits - "Ol' 55"
# [youtube] BeeK37wrBDQ: Downloading webpage
# [download] Destination: ./audio/adeeffbf18cc4c6cb3de6af56cb407cd.mp3
# [download] 100% of 3.89MiB in 00:0083MiB/s ETA 00:006
# [ffmpeg] Post-process file ./audio/adeeffbf18cc4c6cb3de6af56cb407cd.mp3 exists, skipping
# Retrieval of Ol' 55 - Tom Waits is successful.
# 00c4f2efb0b143728113fad1a78d6ce3
# TOOL - Sober
# [youtube] nspxAG12Cpc: Downloading webpage
# [download] Destination: ./audio/00c4f2efb0b143728113fad1a78d6ce3.mp3
# [download] 100% of 4.81MiB in 00:0026MiB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/00c4f2efb0b143728113fad1a78d6ce3.mp3 exists, skipping
# Retrieval of Sober - Tool is successful.
# 0348e3799c164649bc8bd0da206062f3
# Topmodelz - I Think We Re Alone Now - Eurodance Essentials
# [youtube] 7ZOBYycP2Ec: Downloading webpage
# [download] Destination: ./audio/0348e3799c164649bc8bd0da206062f3.mp3
# [download] 100% of 3.11MiB in 00:0003MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/0348e3799c164649bc8bd0da206062f3.mp3 exists, skipping
# Retrieval of I Think We Re Alone Now - Topmodelz is successful.
# 2c07e4cb175d4d5b8a0e2b6291e3f917
# Uncle Kracker - Follow Me [Official Video]
# [youtube] 0Gjx-ZQuQ_Y: Downloading webpage
# [download] Destination: ./audio/2c07e4cb175d4d5b8a0e2b6291e3f917.mp3
# [download] 100% of 3.77MiB in 00:0012MiB/s ETA 00:003
# [ffmpeg] Post-process file ./audio/2c07e4cb175d4d5b8a0e2b6291e3f917.mp3 exists, skipping
# Retrieval of Follow Me - Uncle Kracker is successful.
# 15c1f27eaaa64f5fb9e3cfebff8d2a91
# I'll Wait (2015 Remaster)
# Van Halen - 1984 - I'll Wait
# [youtube] VegvworoMX4: Downloading webpage
# [download] Destination: ./audio/15c1f27eaaa64f5fb9e3cfebff8d2a91.mp3
# [download] 100% of 4.34MiB in 00:0022MiB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/15c1f27eaaa64f5fb9e3cfebff8d2a91.mp3 exists, skipping
# Retrieval of I'll Wait - Van Halen is successful.
# 1c6112908256403faa9812bb7930a8a1
# Van Halen - Panama (Official Music Video)
# [youtube] fuKDBPw8wQA: Downloading webpage
# [download] Destination: ./audio/1c6112908256403faa9812bb7930a8a1.mp3
# [download] 100% of 3.37MiB in 00:0009MiB/s ETA 00:004
# [ffmpeg] Correcting container in "./audio/1c6112908256403faa9812bb7930a8a1.mp3"
# [ffmpeg] Post-process file ./audio/1c6112908256403faa9812bb7930a8a1.mp3 exists, skipping
# Retrieval of Panama - Van Halen is successful.
# 79c46b538c4a42b4ade34c2e78b663d5
# Velvet Revolver - Fall To Pieces (Official Video)
# [youtube] 9JhsUFuqbCM: Downloading webpage
# [download] Destination: ./audio/79c46b538c4a42b4ade34c2e78b663d5.mp3
# [download] 100% of 4.22MiB in 00:0023MiB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/79c46b538c4a42b4ade34c2e78b663d5.mp3 exists, skipping
# Retrieval of Fall To Pieces - Velvet Revolver is successful.
# 6dae25f87a5f45779e0adf97b7537552
# Aquarius
# Within Temptation - Aquarius
# [youtube] EISaNpU3roU: Downloading webpage
# [download] Destination: ./audio/6dae25f87a5f45779e0adf97b7537552.mp3
# [download] 100% of 4.43MiB in 00:0063MiB/s ETA 00:005
# [ffmpeg] Post-process file ./audio/6dae25f87a5f45779e0adf97b7537552.mp3 exists, skipping
# Retrieval of Aquarius - Within Temptation is successful.
# 73972858ae3d464f9f8bf8dcd562aafd
# Within Temptation - Faster (Videoclip)
# [youtube] iQVei5C2N4E: Downloading webpage
# [download] Destination: ./audio/73972858ae3d464f9f8bf8dcd562aafd.mp3
# [download] 100% of 4.07MiB in 00:0095MiB/s ETA 00:004
# [ffmpeg] Post-process file ./audio/73972858ae3d464f9f8bf8dcd562aafd.mp3 exists, skipping
# Retrieval of Faster - Within Temptation is successful.
# b0c1c41a5a024f47ae1eca7a8b5ca59b
# Towards the End
# Within Temptation - Towards The End
# [youtube] RGmCCqAKpIE: Downloading webpage
# [download] Destination: ./audio/b0c1c41a5a024f47ae1eca7a8b5ca59b.mp3
# [download] 100% of 3.51MiB in 00:0025MiB/s ETA 00:0003
# [ffmpeg] Post-process file ./audio/b0c1c41a5a024f47ae1eca7a8b5ca59b.mp3 exists, skipping
# Retrieval of Towards The End - Within Temptation is successful.
# b1b6bc336f78441b8b31da555ccf59d8
# Within Temptation - Forgiven (Lyrics)
# [youtube] a9QSoxoMpfo: Downloading webpage
# [download] Destination: ./audio/b1b6bc336f78441b8b31da555ccf59d8.mp3
# [download] 100% of 4.76MiB in 00:0093MiB/s ETA 00:006
# [ffmpeg] Post-process file ./audio/b1b6bc336f78441b8b31da555ccf59d8.mp3 exists, skipping
# Retrieval of Forgiven - Within Temptation is successful.

# %% [markdown]
# The number of recordings retrieved from Youtube should be 238 which means there are 2 songs missing.

# %%
len(retrieved)
# Out:
# 238

# %% [markdown]
# Our search couldn't retrieve the missing recordings as they do not have their artist names in their Youtube video titles. These songs can be seen below:

# %%
failed
# Out:
# ['144393f2a4a94a3f81907378f4edc095', '42c7fa8a79df4a19932c2fef2ede7b58']

# %% [markdown]
# The search algorithm lists the results according to their relevance. For these recordings, we simply retrieve the very first result that popped up in the search. Note that, these recordings are manually verified to be the same version that is used in DALI_TestSet4ALT.
#
#   - Please check the durations to be extra sure that you downloaded the correct version.

# %%
for item in failed:
    search_title = data.loc[item]['SONG_TITLE'] + data.loc[item]['ARTIST']
    videosSearch = VideosSearch(search_title, limit = 1)
    download_audio_from_youtube(item,videosSearch.result()['result'][0]['link'],SAVE_DIR)
# Out:
# [youtube] 65inlvN8Pq4: Downloading webpage
# [download] ./audio/144393f2a4a94a3f81907378f4edc095.mp3 has already been downloaded
# [download] 100% of 974.13KiB
# [ffmpeg] Post-process file ./audio/144393f2a4a94a3f81907378f4edc095.mp3 exists, skipping
# [youtube] hAm0H5A85gI: Downloading webpage
# [download] ./audio/42c7fa8a79df4a19932c2fef2ede7b58.mp3 has already been downloaded
# [download] 100% of 3.66MiB
# [ffmpeg] Post-process file ./audio/42c7fa8a79df4a19932c2fef2ede7b58.mp3 exists, skipping

# %% [markdown]
# If the number of recordings is equal to 240, you have successfully retrieved the audio files for DALI_TestSet4ALT.

# %%
len(os.listdir(SAVE_DIR))
# Out:
# 240

# %% [markdown]
# Next, we format the data to be utilized within the Kaldi framework. This step is optional.

# %% [markdown]
# ## PART 2: Data formatting for Kaldi
#
# The script below generates the data files required by Kaldi. Once generated, you can directly input the output directory ```DATA_DIR_KALDI``` into your Kaldi pipeline for testing.

# %%
DATA_DIR_KALDI = 'DALI_Test'
if not os.path.exists(DATA_DIR_KALDI):
    os.mkdir(DATA_DIR_KALDI)

# %%
with open(DATA_DIR_KALDI + '/text','w') as wt, open(DATA_DIR_KALDI + '/utt2spk','w') as wu, open(DATA_DIR_KALDI + '/wav.scp','w') as ww:
    for row in data.iterrows():
        data_id = row[1]['GENDER'] + '-' + row[1]['ARTIST'] + '-' + row[0]
        wt.write(data_id + ' ' + row[1]['LYRICS'] + '\n')
        wu.write(data_id + ' ' + row[1]['ARTIST'] + '\n')
        ww.write(data_id + ' ffmpeg -y -i '
              + os.path.abspath(os.path.join('.',SAVE_DIR)) + '/' + row[0] 
              + '.mp3  -ar 16000 -ac 1 -f wav - | sox -t wav - -t wav - |\n' )
